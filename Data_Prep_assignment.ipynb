# %% [markdown]
# <a href="https://colab.research.google.com/github/Pradeep1694/Data-Prep-Feature-Engineering/blob/main/Data_Prep_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Data
data = {
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female'],
    'City': ['Mumbai', 'Delhi', 'Chennai', 'Mumbai', 'Delhi'],
    'Size': ['Small', 'Large', 'Medium', 'Large', 'Small'],
    'Age': [25, 45, 32, 60, 28],
    'Fare': [15, 300, 85, 450, 20]
}

df = pd.DataFrame(data)

# Task 1:

#Gender → Label Encoding
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])

print(df)
# Out:
#    Gender     City    Size  Age  Fare
# 0       1   Mumbai   Small   25    15
# 1       0    Delhi   Large   45   300
# 2       0  Chennai  Medium   32    85
# 3       1   Mumbai   Large   60   450
# 4       0    Delhi   Small   28    20

# %%
df = pd.DataFrame(data)

# 2. City → One-Hot Encoding (drop one column)
df = pd.get_dummies(df, columns=['City'], drop_first=True)

print(df)
# Out:
#    Gender    Size  Age  Fare  City_Delhi  City_Mumbai
# 0    Male   Small   25    15       False         True
# 1  Female   Large   45   300        True        False
# 2  Female  Medium   32    85       False        False
# 3    Male   Large   60   450       False         True
# 4  Female   Small   28    20        True        False

# %%
df = pd.DataFrame(data)

# Label Encoding with order
size_mapping = {'Small': 0, 'Medium': 1, 'Large': 2}
df['Size'] = df['Size'].map(size_mapping)

print(df)
# Out:
#    Gender     City  Size  Age  Fare
# 0    Male   Mumbai     0   25    15
# 1  Female    Delhi     2   45   300
# 2  Female  Chennai     1   32    85
# 3    Male   Mumbai     2   60   450
# 4  Female    Delhi     0   28    20

# %%
df = pd.DataFrame(data)

# Task 2: Feature Scaling
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
df[['Age', 'Fare']] = scaler.fit_transform(df[['Age', 'Fare']])

print(df)
# Out:
#    Gender     City    Size       Age      Fare
# 0    Male   Mumbai   Small -0.411765 -0.250000
# 1  Female    Delhi   Large  0.764706  0.767857
# 2  Female  Chennai  Medium  0.000000  0.000000
# 3    Male   Mumbai   Large  1.647059  1.303571
# 4  Female    Delhi   Small -0.235294 -0.232143
